# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/AviationData2.csv')
# Out:
# /var/folders/ym/68nrz1n97wj0gz5413bhpqs80000gn/T/ipykernel_15585/1579995561.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/AviationData2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
df.T
# Out:
#                                   0               1               2      \
# Event.Id                 20001218X45444  20001218X45447  20061025X01555
# Investigation.Type             Accident        Accident        Accident
# Accident.Number              SEA87LA080      LAX94LA336      NYC07LA005
# Event.Date                     10/24/48         7/19/62         8/30/74
# Location                MOOSE CREEK, ID  BRIDGEPORT, CA   Saltville, VA
# Country                   United States   United States   United States
# Latitude                            NaN             NaN       36.922223
# Longitude                           NaN             NaN      -81.878056
# Airport.Code                        NaN             NaN             NaN
# Airport.Name                        NaN             NaN             NaN
# Injury.Severity                Fatal(2)        Fatal(4)        Fatal(3)
# Aircraft.damage               Destroyed       Destroyed       Destroyed
# ...

# %%
df = df[df['Investigation.Type'] == 'Accident']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85015 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                85015 non-null  object
#  1   Investigation.Type      85015 non-null  object
#  2   Accident.Number         85015 non-null  object
#  3   Event.Date              85015 non-null  object
#  4   Location                84975 non-null  object
#  5   Country                 84809 non-null  object
#  6   Latitude                33398 non-null  object
#  7   Longitude               33389 non-null  object
#  8   Airport.Code            48177 non-null  object
#  9   Airport.Name            50675 non-null  object
#  10  Injury.Severity         84688 non-null  object
#  11  Aircraft.damage         83555 non-null  object
#  12  Aircraft.Category       30535 non-null  object
#  13  Registration.Number     83908 non-null  object
# ...

# %%
df['Make'] = df['Make'].str.title()
# df['Make'] = df['Make'].str.strip()

# %%
df = df[(df['Number.of.Engines'] == 3) | (df['Number.of.Engines'] == 4)]

# %%
df.T
# Out:
#                                                 129                    155    \
# Event.Id                               20020917X02397         20020917X01909
# Investigation.Type                           Accident               Accident
# Accident.Number                            MIA82FA034             DCA82AA013
# Event.Date                                    1/19/82                1/23/82
# Location                                    MIAMI, FL             BOSTON, MA
# Country                                 United States          United States
# Latitude                                          NaN                    NaN
# Longitude                                         NaN                    NaN
# Airport.Code                                      MIA                    NaN
# Airport.Name                               MIAMI INTL   BOSTON-LOGAN INTER'L
# Injury.Severity                             Non-Fatal               Fatal(2)
# ...

# %%
df['Purpose.of.flight'].value_counts()
# Out:
# Purpose.of.flight
# Personal                     46932
# Instructional                10066
# Unknown                       4623
# Aerial Application            4587
# Business                      3703
# Positioning                   1496
# Other Work Use                1106
# Ferry                          742
# Aerial Observation             705
# Public Aircraft                575
# Executive/corporate            469
# Flight Test                    363
# Skydiving                      175
# External Load                  108
# Banner Tow                      99
# Public Aircraft - Federal       93
# Public Aircraft - Local         71
# Air Race show                   66
# Public Aircraft - State         61
# Air Race/show                   48
# Glider Tow                      38
# Firefighting                    33
# Air Drop                         8
# ASHO                             5
# PUBS                             4
# PUBL                             1
# ...

# %%
df['Injury.Severity'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 432 entries, 129 to 88777
# Series name: Injury.Severity
# Non-Null Count  Dtype
# --------------  -----
# 430 non-null    object
# dtypes: object(1)
# memory usage: 22.9+ KB

# %%
df['Make'].value_counts().head(10)
# Out:
# Make
# Boeing               199
# Mcdonnell Douglas     69
# Douglas               59
# Lockheed              46
# Dassault               7
# Dassault-Breguet       6
# De Havilland           6
# Dassault Aviation      4
# British Aerospace      3
# Canadair               2
# Name: count, dtype: int64

# %%
df['Broad.phase.of.flight'].value_counts().head(20)
# Out:
# Broad.phase.of.flight
# Taxi           61
# Takeoff        55
# Cruise         54
# Landing        53
# Approach       31
# Climb          27
# Standing       26
# Descent        25
# Maneuvering     9
# Go-around       4
# Other           1
# Unknown         1
# Name: count, dtype: int64

# %%
df.groupby(['Make', 'Injury.Severity']).count().T
# Out:
# Make                   107.5 Flying Corporation 177Mf Llc 1St Ftr Gp  \
# Injury.Severity                        Fatal(1) Non-Fatal   Fatal(1)
# Event.Id                                      1         1          1
# Investigation.Type                            1         1          1
# Accident.Number                               1         1          1
# Event.Date                                    1         1          1
# Location                                      1         1          1
# Country                                       1         1          1
# Latitude                                      1         1          0
# Longitude                                     1         1          0
# Airport.Code                                  1         0          0
# Airport.Name                                  1         0          0
# Aircraft.damage                               1         1          1
# Aircraft.Category                             0         1          0
# ...

# %%
dfC = df[df['Make'] == 'Cessna']

# %%
dfC['Injury.Severity'].count
# Out:
# <bound method Series.count of 5646     Non-Fatal
# 25445     Fatal(1)
# Name: Injury.Severity, dtype: object>

# %%
dfP = df[df['Make'] == 'Piper']

# %%
dfP['Injury.Severity'].value_counts()
# Out:
# Injury.Severity
# Non-Fatal    1
# Name: count, dtype: int64

# %%
df['Total.Uninjured'].value_counts()
# Out:
# Total.Uninjured
# 0.0      63
# 3.0      57
# 5.0      24
# 2.0      24
# 4.0      20
#          ..
# 182.0     1
# 211.0     1
# 12.0      1
# 25.0      1
# 397.0     1
# Name: count, Length: 154, dtype: int64

# %%
df['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# VMC    71236
# IMC     5408
# UNK      545
# Unk      151
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.histplot(data=df,x="Total.Fatal.Injuries", bins=np.arange(0,50,1), hue="Aircraft.damage")
# Out:
# <Axes: xlabel='Total.Fatal.Injuries', ylabel='Count'>

# %%
df["Aircraft.damage"]
# Out:
# 129      Substantial
# 155        Destroyed
# 230            Minor
# 344      Substantial
# 558        Destroyed
#             ...
# 86199          Minor
# 86732    Substantial
# 87225    Substantial
# 87804    Substantial
# 88777      Destroyed
# Name: Aircraft.damage, Length: 432, dtype: object
