# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Data/AviationDataClean.csv")
df["Make-Model"] = df["Make"]+"-"+df["Model"]
df
# Out:
# /var/folders/ym/68nrz1n97wj0gz5413bhpqs80000gn/T/ipykernel_1105/173988840.py:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data/AviationDataClean.csv")
#        Unnamed: 0        Event.Id Investigation.Type Accident.Number  \
# 0               1  20001218X45447           Accident      LAX94LA336
# 1               2  20061025X01555           Accident      NYC07LA005
# 2               6  20001218X45446           Accident      CHI81LA106
# 3               7  20020909X01562           Accident      SEA82DA022
# 4               8  20020909X01561           Accident      NYC82DA015
# ...           ...             ...                ...             ...
# 48595       88858  20221211106438           Accident      ERA23LA083
# 48596       88861  20221215106460           Accident      ERA23LA088
# 48597       88865  20221212106444           Accident      ERA23LA085
# 48598       88869  20221213106455           Accident      WPR23LA065
# 48599       88877  20221219106470           Accident      ERA23LA091
#
#        Event.Date          Location        Country   Latitude  Longitude  \
# 0      1962-07-19    BRIDGEPORT, CA  United States        NaN        NaN
# 1      1974-08-30     Saltville, VA  United States  36.922223 -81.878056
# 2      1981-08-01        COTTON, MN  United States        NaN        NaN
# 3      1982-01-01       PULLMAN, WA  United States        NaN        NaN
# 4      1982-01-01  EAST HANOVER, NJ  United States        NaN        NaN
# ...           ...               ...            ...        ...        ...
# 48595  2022-12-09  Hawkinsville, GA  United States    321814N   0832534W
# 48596  2022-12-10     Alabaster, AL  United States    331040N   0086470W
# 48597  2022-12-12     Knoxville, TN  United States    355745N   0835218W
# 48598  2022-12-13     Lewistown, MT  United States    047257N   0109280W
# 48599  2022-12-16   Brooksville, FL  United States    282825N   0822719W
#
#       Airport.Code  ... Broad.phase.of.flight   Report.Status  \
# 0              NaN  ...               Unknown  Probable Cause
# 1              NaN  ...                Cruise  Probable Cause
# 2              NaN  ...               Unknown  Probable Cause
# 3              NaN  ...               Takeoff  Probable Cause
# 4              N58  ...               Landing  Probable Cause
# ...            ...  ...                   ...             ...
# 48595          51A  ...                   NaN             NaN
# 48596          EET  ...                   NaN             NaN
# 48597          DKX  ...                   NaN             NaN
# 48598         KLWT  ...                   NaN             NaN
# 48599          BKV  ...                   NaN             NaN
#
#       Publication.Date Survive total.passengers Month  Year Fraction_fatal  \
# 0           19-09-1996   False              4.0     7  1962            1.0
# 1           26-02-2007   False              3.0     8  1974            1.0
# 2           06-11-2001   False              4.0     8  1981            1.0
# 3           01-01-1982    True              2.0     1  1982            0.0
# 4           01-01-1982    True              2.0     1  1982            0.0
# ...                ...     ...              ...   ...   ...            ...
# 48595       15-12-2022    True              1.0    12  2022            0.0
# 48596       19-12-2022    True              2.0    12  2022            0.0
# 48597       15-12-2022    True              1.0    12  2022            0.0
# 48598       14-12-2022    True              1.0    12  2022            0.0
# 48599       23-12-2022    True              1.0    12  2022            0.0
#
#        Fraction_uninjured      Make-Model
# 0                     0.0  Piper-PA24-180
# 1                     0.0     Cessna-172M
# 2                     0.0      Cessna-180
# 3                     1.0      Cessna-140
# 4                     1.0     Cessna-401B
# ...                   ...             ...
# 48595                 0.0     Piper-PA-44
# 48596                 1.0     Cessna-305A
# 48597                 1.0      Cessna-172
# 48598                 1.0      Piper-PA42
# 48599                 0.0    Cessna-R172K
#
# [48600 rows x 39 columns]

# %%
df1 = pd.DataFrame([["Cessa 152", 2],
                  ["Cessa 152", 2],["Cessa 152", 2],
                   ["Cessa 501", np.NaN],
                  ["Cessa 501", 1],
                  ],columns=["Make-Model","Number.of.Engines"])

df1
# Out:
#   Make-Model  Number.of.Engines
# 0  Cessa 152                2.0
# 1  Cessa 152                2.0
# 2  Cessa 152                2.0
# 3  Cessa 501                NaN
# 4  Cessa 501                1.0

# %%
lookup=df[["Make-Model","Number.of.Engines"]].groupby("Make-Model").median()
lookup
# Out:
#                             Number.of.Engines
# Make-Model
# Beech-100                                 2.0
# Beech-17                                  1.0
# Beech-18                                  2.0
# Beech-18-C45G                             2.0
# Beech-18G                                 2.0
# ...                                       ...
# Piper-PT-46                               1.0
# Piper-Saratoga II TC PA32-                1.0
# Piper-Seneca                              2.0
# Piper-TG8-J3C-65                          1.0
# Piper-TITAN TORNADO II D                  1.0
#
# [2253 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48600 entries, 0 to 48599
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              48600 non-null  int64
#  1   Event.Id                48600 non-null  object
#  2   Investigation.Type      48600 non-null  object
#  3   Accident.Number         48600 non-null  object
#  4   Event.Date              48600 non-null  object
#  5   Location                48589 non-null  object
#  6   Country                 48461 non-null  object
#  7   Latitude                16410 non-null  object
#  8   Longitude               16409 non-null  object
#  9   Airport.Code            29889 non-null  object
#  10  Airport.Name            31427 non-null  object
#  11  Injury.Severity         48571 non-null  object
#  12  Aircraft.damage         48405 non-null  object
#  13  Aircraft.Category       14786 non-null  object
#  14  Registration.Number     48585 non-null  object
#  15  Make                    48600 non-null  object
#  16  Model                   48596 non-null  object
#  17  Amateur.Built           48590 non-null  object
#  18  Number.of.Engines       48600 non-null  float64
#  19  Engine.Type             47533 non-null  object
#  20  FAR.Description         14763 non-null  object
#  21  Schedule                3944 non-null   object
#  22  Purpose.of.flight       47651 non-null  object
#  23  Air.carrier             6926 non-null   object
#  24  Total.Fatal.Injuries    48600 non-null  float64
#  25  Total.Serious.Injuries  48600 non-null  float64
#  26  Total.Minor.Injuries    48600 non-null  float64
#  27  Total.Uninjured         48600 non-null  float64
#  28  Weather.Condition       48061 non-null  object
#  29  Broad.phase.of.flight   38103 non-null  object
#  30  Report.Status           47023 non-null  object
#  31  Publication.Date        40189 non-null  object
#  32  Survive                 48600 non-null  bool
#  33  total.passengers        48600 non-null  float64
#  34  Month                   48600 non-null  int64
#  35  Year                    48600 non-null  int64
#  36  Fraction_fatal          48565 non-null  float64
#  37  Fraction_uninjured      48565 non-null  float64
#  38  Make-Model              48596 non-null  object
# dtypes: bool(1), float64(8), int64(3), object(27)
# memory usage: 14.1+ MB

# %%
df = df.dropna(subset="Make-Model")
df.loc["Number.of.Engines"] = df["Make-Model"].map(lambda x: lookup.loc[x])
# Out:
# /var/folders/ym/68nrz1n97wj0gz5413bhpqs80000gn/T/ipykernel_1105/2717365897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc["Number.of.Engines"] = df["Make-Model"].map(lambda x: lookup.loc[x])

# %%
import seaborn as sns

sns.histplot(data=df,x="Number.of.Engines")
# Out:
# <Axes: xlabel='Number.of.Engines', ylabel='Count'>

# %%
df.groupby("Make-Model").count().sort_values(by="Event.Id",ascending=False)
# Out:
#                           Unnamed: 0  Event.Id  Investigation.Type  \
# Make-Model
# Cessna-152                      2323      2323                2323
# Cessna-172                      1661      1661                1661
# Cessna-172N                     1142      1142                1142
# Piper-PA-28-140                  915       915                 915
# Cessna-150                       798       798                 798
# ...                              ...       ...                 ...
# Cessna-210MII                      1         1                   1
# Cessna-210 NII                     1         1                   1
# Cessna-210 D                       1         1                   1
# Cessna-210 5A(205A)                1         1                   1
# Piper-TITAN TORNADO II D           1         1                   1
#
#                           Accident.Number  Event.Date  Location  Country  \
# Make-Model
# Cessna-152                           2323        2323      2322     2323
# Cessna-172                           1661        1661      1660     1659
# Cessna-172N                          1142        1142      1142     1139
# Piper-PA-28-140                       915         915       915      914
# Cessna-150                            798         798       798      797
# ...                                   ...         ...       ...      ...
# Cessna-210MII                           1           1         1        1
# Cessna-210 NII                          1           1         1        1
# Cessna-210 D                            1           1         1        1
# Cessna-210 5A(205A)                     1           1         1        1
# Piper-TITAN TORNADO II D                1           1         1        1
#
#                           Latitude  Longitude  Airport.Code  ...  \
# Make-Model                                                   ...
# Cessna-152                     413        413          1563  ...
# Cessna-172                     744        744          1201  ...
# Cessna-172N                    340        339           754  ...
# Piper-PA-28-140                235        234           586  ...
# Cessna-150                     182        182           477  ...
# ...                            ...        ...           ...  ...
# Cessna-210MII                    0          0             1  ...
# Cessna-210 NII                   0          0             1  ...
# Cessna-210 D                     1          1             1  ...
# Cessna-210 5A(205A)              1          1             1  ...
# Piper-TITAN TORNADO II D         1          1             1  ...
#
#                           Weather.Condition  Broad.phase.of.flight  \
# Make-Model
# Cessna-152                             2314                   2100
# Cessna-172                             1628                   1013
# Cessna-172N                            1137                    970
# Piper-PA-28-140                         905                    790
# Cessna-150                              786                    659
# ...                                     ...                    ...
# Cessna-210MII                             1                      1
# Cessna-210 NII                            1                      1
# Cessna-210 D                              1                      1
# Cessna-210 5A(205A)                       1                      0
# Piper-TITAN TORNADO II D                  1                      0
#
#                           Report.Status  Publication.Date  Survive  \
# Make-Model
# Cessna-152                         2301              1788     2323
# Cessna-172                         1566              1431     1661
# Cessna-172N                        1129               971     1142
# Piper-PA-28-140                     887               738      915
# Cessna-150                          760               639      798
# ...                                 ...               ...      ...
# Cessna-210MII                         1                 0        1
# Cessna-210 NII                        1                 0        1
# Cessna-210 D                          1                 1        1
# Cessna-210 5A(205A)                   1                 1        1
# Piper-TITAN TORNADO II D              1                 1        1
#
#                           total.passengers  Month  Year  Fraction_fatal  \
# Make-Model
# Cessna-152                            2323   2323  2323            2323
# Cessna-172                            1661   1661  1661            1658
# Cessna-172N                           1142   1142  1142            1140
# Piper-PA-28-140                        915    915   915             915
# Cessna-150                             798    798   798             797
# ...                                    ...    ...   ...             ...
# Cessna-210MII                            1      1     1               1
# Cessna-210 NII                           1      1     1               1
# Cessna-210 D                             1      1     1               1
# Cessna-210 5A(205A)                      1      1     1               1
# Piper-TITAN TORNADO II D                 1      1     1               1
#
#                           Fraction_uninjured
# Make-Model
# Cessna-152                              2323
# Cessna-172                              1658
# Cessna-172N                             1140
# Piper-PA-28-140                          915
# Cessna-150                               797
# ...                                      ...
# Cessna-210MII                              1
# Cessna-210 NII                             1
# Cessna-210 D                               1
# Cessna-210 5A(205A)                        1
# Piper-TITAN TORNADO II D                   1
#
# [2253 rows x 38 columns]
